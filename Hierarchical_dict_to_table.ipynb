# %% [markdown]
# # Convert hierarchical JSON to pd.DataFrame
#
# **Task**: given a nested, hierarchical JSON (or Python `dict`), normalize it
# to a usable table representation such as a valid `pandas.DataFrame`.
#
# **Sample dict**:
# ```python
# po_dict = {'ABC': {"open": {},
#                    "updated":
#                        {"12": {"22334": 5, "22335": 5},
#                         "01": {"22335": 1, "22336": 2, "22337": 2},
#                         "02": {"22337": 8, "order": 2},
#                         "03": {"order": 5}}},
#             'DEF': {"open": {},
#                     "updated":
#                        {"12": {"22338": 5, "22339": 5},
#                         "01": {"22339": 1, "22340": 2, "22341": 2},
#                         "02": {"22341": 8, "order": 2},
#                         "03": {"order": 5}}},
#                     }
# ```
#
# **Expected outcome**:
# ```
# material | state   | month | po_nb | po_value
# ---------------------------------------------
# ABC      | open    |       |       |
# ABC      | updated | 12    | 22334 | 5
# ABC      | updated | 12    | 22335 | 5
# ABC      | updated | 1     | 22335 | 1
# ABC      | updated | 1     | 22336 | 2
# ABC      | updated | 1     | 22337 | 2
# ABC      | updated | 2     | 22337 | 8
# ABC      | updated | 2     | order | 2
# ABC      | updated | 3     | order | 5
# DEF      | open    |       |       |
# ...
# ```

# %%
# sample sparse dict

sparse_sample_dict = {
  "ABC": {
    "open": {},
    "updated": {
      "12": {
        "22334": 5,
        "22335": 5
      },
      "01": {
        "22335": 1,
        "22336": 2,
        "22337": 2
      },
      "02": {
        "22337": 8,
        "order": 2
      },
      "03": {
        "order": 5
      }
    }
  },
  "DEF": {
    "open": {},
    "updated": {
      "12": {"22338": 5, "22339": 5},
      "01": {"22339": 1, "22340": 2, "22341": 2},
      "02": {"22341": 8, "order": 2},
      "03": {"order": 5}
    }
  }
}

# %%
# PoC for recursive "flattening" of a sparse dict into a list of
#  lists (LOL) where each inner list equals one row (ROW) in the
#  new table

def rec(d, row=None, lol= None):
    print(f"\nfunction called; got:\n d: {d};\n ROW: {row};\n LOL: {lol}")

    if not row:
        row = []
    if not lol:
        lol = []

    for k, v in d.items():

        row.append(k)
        print(f"\nadded key {k} to ROW:\n{row}")

        if v and isinstance(v, dict):
            # row continues, so...
            print(f"\nrow continues; recursing...")
            # 1. go deeper and receive updated row & lol
            row, lol = rec(d=v, row=row, lol=lol)
            print(f"\nreceived:\n ROW: {row}\n LOL: {lol}")

        else:
            # row ends, so...
            # 1. add current val to row
            row.append(v)
            print(f"\nROW ends here; added {v} to ROW:\n{row}")
            # 2. add finalized row to lol
            lol.append(row[:])
            print(f"\nappended finalized row to LOL:\n{lol}")
            # 3. remove latest cell from row
            row.pop()
            print(f"\nremoved latest entry from ROW again:\n{row}")

        # current value processed, so...
        print(f"\ncurrent val {v} processed.")
        # 1. remove latest level from row
        row.pop()
        print(f"\nremoved latest level from ROW:\n{row}")

    # all items processed, so...
    print(f"\nall items iterated; returning:")
    # 1. return updated row & lol
    print(f" ROW:\n{row}")
    print(f" LOL:\n{lol}")
    return row, lol

# call the function
_, table = rec(d=sparse_sample_dict)
# Out:
# function called; got:
#  d: {'ABC': {'open': {}, 'updated': {'12': {'22334': 5, '22335': 5}, '01': {'22335': 1, '22336': 2, '22337': 2}, '02': {'22337': 8, 'order': 2}, '03': {'order': 5}}}, 'DEF': {'open': {}, 'updated': {'12': {'22338': 5, '22339': 5}, '01': {'22339': 1, '22340': 2, '22341': 2}, '02': {'22341': 8, 'order': 2}, '03': {'order': 5}}}};
#  ROW: None;
#  LOL: None
#
# added key ABC to ROW:
# ['ABC']
#
# row continues; recursing...
#
# function called; got:
#  d: {'open': {}, 'updated': {'12': {'22334': 5, '22335': 5}, '01': {'22335': 1, '22336': 2, '22337': 2}, '02': {'22337': 8, 'order': 2}, '03': {'order': 5}}};
#  ROW: ['ABC'];
#  LOL: []
#
# added key open to ROW:
# ['ABC', 'open']
#
# ROW ends here; added {} to ROW:
# ['ABC', 'open', {}]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}]]
#
# removed latest entry from ROW again:
# ['ABC', 'open']
#
# current val {} processed.
#
# removed latest level from ROW:
# ['ABC']
#
# added key updated to ROW:
# ['ABC', 'updated']
#
# row continues; recursing...
#
# function called; got:
#  d: {'12': {'22334': 5, '22335': 5}, '01': {'22335': 1, '22336': 2, '22337': 2}, '02': {'22337': 8, 'order': 2}, '03': {'order': 5}};
#  ROW: ['ABC', 'updated'];
#  LOL: [['ABC', 'open', {}]]
#
# added key 12 to ROW:
# ['ABC', 'updated', '12']
#
# row continues; recursing...
#
# function called; got:
#  d: {'22334': 5, '22335': 5};
#  ROW: ['ABC', 'updated', '12'];
#  LOL: [['ABC', 'open', {}]]
#
# added key 22334 to ROW:
# ['ABC', 'updated', '12', '22334']
#
# ROW ends here; added 5 to ROW:
# ['ABC', 'updated', '12', '22334', 5]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5]]
#
# removed latest entry from ROW again:
# ['ABC', 'updated', '12', '22334']
#
# current val 5 processed.
#
# removed latest level from ROW:
# ['ABC', 'updated', '12']
#
# added key 22335 to ROW:
# ['ABC', 'updated', '12', '22335']
#
# ROW ends here; added 5 to ROW:
# ['ABC', 'updated', '12', '22335', 5]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5]]
#
# removed latest entry from ROW again:
# ['ABC', 'updated', '12', '22335']
#
# current val 5 processed.
#
# removed latest level from ROW:
# ['ABC', 'updated', '12']
#
# all items iterated; returning:
#  ROW:
# ['ABC', 'updated', '12']
#  LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5]]
#
# received:
#  ROW: ['ABC', 'updated', '12']
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5]]
#
# current val {'22334': 5, '22335': 5} processed.
#
# removed latest level from ROW:
# ['ABC', 'updated']
#
# added key 01 to ROW:
# ['ABC', 'updated', '01']
#
# row continues; recursing...
#
# function called; got:
#  d: {'22335': 1, '22336': 2, '22337': 2};
#  ROW: ['ABC', 'updated', '01'];
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5]]
#
# added key 22335 to ROW:
# ['ABC', 'updated', '01', '22335']
#
# ROW ends here; added 1 to ROW:
# ['ABC', 'updated', '01', '22335', 1]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1]]
#
# removed latest entry from ROW again:
# ['ABC', 'updated', '01', '22335']
#
# current val 1 processed.
#
# removed latest level from ROW:
# ['ABC', 'updated', '01']
#
# added key 22336 to ROW:
# ['ABC', 'updated', '01', '22336']
#
# ROW ends here; added 2 to ROW:
# ['ABC', 'updated', '01', '22336', 2]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2]]
#
# removed latest entry from ROW again:
# ['ABC', 'updated', '01', '22336']
#
# current val 2 processed.
#
# removed latest level from ROW:
# ['ABC', 'updated', '01']
#
# added key 22337 to ROW:
# ['ABC', 'updated', '01', '22337']
#
# ROW ends here; added 2 to ROW:
# ['ABC', 'updated', '01', '22337', 2]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2]]
#
# removed latest entry from ROW again:
# ['ABC', 'updated', '01', '22337']
#
# current val 2 processed.
#
# removed latest level from ROW:
# ['ABC', 'updated', '01']
#
# all items iterated; returning:
#  ROW:
# ['ABC', 'updated', '01']
#  LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2]]
#
# received:
#  ROW: ['ABC', 'updated', '01']
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2]]
#
# current val {'22335': 1, '22336': 2, '22337': 2} processed.
#
# removed latest level from ROW:
# ['ABC', 'updated']
#
# added key 02 to ROW:
# ['ABC', 'updated', '02']
#
# row continues; recursing...
#
# function called; got:
#  d: {'22337': 8, 'order': 2};
#  ROW: ['ABC', 'updated', '02'];
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2]]
#
# added key 22337 to ROW:
# ['ABC', 'updated', '02', '22337']
#
# ROW ends here; added 8 to ROW:
# ['ABC', 'updated', '02', '22337', 8]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8]]
#
# removed latest entry from ROW again:
# ['ABC', 'updated', '02', '22337']
#
# current val 8 processed.
#
# removed latest level from ROW:
# ['ABC', 'updated', '02']
#
# added key order to ROW:
# ['ABC', 'updated', '02', 'order']
#
# ROW ends here; added 2 to ROW:
# ['ABC', 'updated', '02', 'order', 2]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2]]
#
# removed latest entry from ROW again:
# ['ABC', 'updated', '02', 'order']
#
# current val 2 processed.
#
# removed latest level from ROW:
# ['ABC', 'updated', '02']
#
# all items iterated; returning:
#  ROW:
# ['ABC', 'updated', '02']
#  LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2]]
#
# received:
#  ROW: ['ABC', 'updated', '02']
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2]]
#
# current val {'22337': 8, 'order': 2} processed.
#
# removed latest level from ROW:
# ['ABC', 'updated']
#
# added key 03 to ROW:
# ['ABC', 'updated', '03']
#
# row continues; recursing...
#
# function called; got:
#  d: {'order': 5};
#  ROW: ['ABC', 'updated', '03'];
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2]]
#
# added key order to ROW:
# ['ABC', 'updated', '03', 'order']
#
# ROW ends here; added 5 to ROW:
# ['ABC', 'updated', '03', 'order', 5]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5]]
#
# removed latest entry from ROW again:
# ['ABC', 'updated', '03', 'order']
#
# current val 5 processed.
#
# removed latest level from ROW:
# ['ABC', 'updated', '03']
#
# all items iterated; returning:
#  ROW:
# ['ABC', 'updated', '03']
#  LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5]]
#
# received:
#  ROW: ['ABC', 'updated', '03']
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5]]
#
# current val {'order': 5} processed.
#
# removed latest level from ROW:
# ['ABC', 'updated']
#
# all items iterated; returning:
#  ROW:
# ['ABC', 'updated']
#  LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5]]
#
# received:
#  ROW: ['ABC', 'updated']
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5]]
#
# current val {'12': {'22334': 5, '22335': 5}, '01': {'22335': 1, '22336': 2, '22337': 2}, '02': {'22337': 8, 'order': 2}, '03': {'order': 5}} processed.
#
# removed latest level from ROW:
# ['ABC']
#
# all items iterated; returning:
#  ROW:
# ['ABC']
#  LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5]]
#
# received:
#  ROW: ['ABC']
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5]]
#
# current val {'open': {}, 'updated': {'12': {'22334': 5, '22335': 5}, '01': {'22335': 1, '22336': 2, '22337': 2}, '02': {'22337': 8, 'order': 2}, '03': {'order': 5}}} processed.
#
# removed latest level from ROW:
# []
#
# added key DEF to ROW:
# ['DEF']
#
# row continues; recursing...
#
# function called; got:
#  d: {'open': {}, 'updated': {'12': {'22338': 5, '22339': 5}, '01': {'22339': 1, '22340': 2, '22341': 2}, '02': {'22341': 8, 'order': 2}, '03': {'order': 5}}};
#  ROW: ['DEF'];
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5]]
#
# added key open to ROW:
# ['DEF', 'open']
#
# ROW ends here; added {} to ROW:
# ['DEF', 'open', {}]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}]]
#
# removed latest entry from ROW again:
# ['DEF', 'open']
#
# current val {} processed.
#
# removed latest level from ROW:
# ['DEF']
#
# added key updated to ROW:
# ['DEF', 'updated']
#
# row continues; recursing...
#
# function called; got:
#  d: {'12': {'22338': 5, '22339': 5}, '01': {'22339': 1, '22340': 2, '22341': 2}, '02': {'22341': 8, 'order': 2}, '03': {'order': 5}};
#  ROW: ['DEF', 'updated'];
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}]]
#
# added key 12 to ROW:
# ['DEF', 'updated', '12']
#
# row continues; recursing...
#
# function called; got:
#  d: {'22338': 5, '22339': 5};
#  ROW: ['DEF', 'updated', '12'];
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}]]
#
# added key 22338 to ROW:
# ['DEF', 'updated', '12', '22338']
#
# ROW ends here; added 5 to ROW:
# ['DEF', 'updated', '12', '22338', 5]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5]]
#
# removed latest entry from ROW again:
# ['DEF', 'updated', '12', '22338']
#
# current val 5 processed.
#
# removed latest level from ROW:
# ['DEF', 'updated', '12']
#
# added key 22339 to ROW:
# ['DEF', 'updated', '12', '22339']
#
# ROW ends here; added 5 to ROW:
# ['DEF', 'updated', '12', '22339', 5]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5]]
#
# removed latest entry from ROW again:
# ['DEF', 'updated', '12', '22339']
#
# current val 5 processed.
#
# removed latest level from ROW:
# ['DEF', 'updated', '12']
#
# all items iterated; returning:
#  ROW:
# ['DEF', 'updated', '12']
#  LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5]]
#
# received:
#  ROW: ['DEF', 'updated', '12']
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5]]
#
# current val {'22338': 5, '22339': 5} processed.
#
# removed latest level from ROW:
# ['DEF', 'updated']
#
# added key 01 to ROW:
# ['DEF', 'updated', '01']
#
# row continues; recursing...
#
# function called; got:
#  d: {'22339': 1, '22340': 2, '22341': 2};
#  ROW: ['DEF', 'updated', '01'];
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5]]
#
# added key 22339 to ROW:
# ['DEF', 'updated', '01', '22339']
#
# ROW ends here; added 1 to ROW:
# ['DEF', 'updated', '01', '22339', 1]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1]]
#
# removed latest entry from ROW again:
# ['DEF', 'updated', '01', '22339']
#
# current val 1 processed.
#
# removed latest level from ROW:
# ['DEF', 'updated', '01']
#
# added key 22340 to ROW:
# ['DEF', 'updated', '01', '22340']
#
# ROW ends here; added 2 to ROW:
# ['DEF', 'updated', '01', '22340', 2]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2]]
#
# removed latest entry from ROW again:
# ['DEF', 'updated', '01', '22340']
#
# current val 2 processed.
#
# removed latest level from ROW:
# ['DEF', 'updated', '01']
#
# added key 22341 to ROW:
# ['DEF', 'updated', '01', '22341']
#
# ROW ends here; added 2 to ROW:
# ['DEF', 'updated', '01', '22341', 2]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2]]
#
# removed latest entry from ROW again:
# ['DEF', 'updated', '01', '22341']
#
# current val 2 processed.
#
# removed latest level from ROW:
# ['DEF', 'updated', '01']
#
# all items iterated; returning:
#  ROW:
# ['DEF', 'updated', '01']
#  LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2]]
#
# received:
#  ROW: ['DEF', 'updated', '01']
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2]]
#
# current val {'22339': 1, '22340': 2, '22341': 2} processed.
#
# removed latest level from ROW:
# ['DEF', 'updated']
#
# added key 02 to ROW:
# ['DEF', 'updated', '02']
#
# row continues; recursing...
#
# function called; got:
#  d: {'22341': 8, 'order': 2};
#  ROW: ['DEF', 'updated', '02'];
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2]]
#
# added key 22341 to ROW:
# ['DEF', 'updated', '02', '22341']
#
# ROW ends here; added 8 to ROW:
# ['DEF', 'updated', '02', '22341', 8]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2], ['DEF', 'updated', '02', '22341', 8]]
#
# removed latest entry from ROW again:
# ['DEF', 'updated', '02', '22341']
#
# current val 8 processed.
#
# removed latest level from ROW:
# ['DEF', 'updated', '02']
#
# added key order to ROW:
# ['DEF', 'updated', '02', 'order']
#
# ROW ends here; added 2 to ROW:
# ['DEF', 'updated', '02', 'order', 2]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2], ['DEF', 'updated', '02', '22341', 8], ['DEF', 'updated', '02', 'order', 2]]
#
# removed latest entry from ROW again:
# ['DEF', 'updated', '02', 'order']
#
# current val 2 processed.
#
# removed latest level from ROW:
# ['DEF', 'updated', '02']
#
# all items iterated; returning:
#  ROW:
# ['DEF', 'updated', '02']
#  LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2], ['DEF', 'updated', '02', '22341', 8], ['DEF', 'updated', '02', 'order', 2]]
#
# received:
#  ROW: ['DEF', 'updated', '02']
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2], ['DEF', 'updated', '02', '22341', 8], ['DEF', 'updated', '02', 'order', 2]]
#
# current val {'22341': 8, 'order': 2} processed.
#
# removed latest level from ROW:
# ['DEF', 'updated']
#
# added key 03 to ROW:
# ['DEF', 'updated', '03']
#
# row continues; recursing...
#
# function called; got:
#  d: {'order': 5};
#  ROW: ['DEF', 'updated', '03'];
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2], ['DEF', 'updated', '02', '22341', 8], ['DEF', 'updated', '02', 'order', 2]]
#
# added key order to ROW:
# ['DEF', 'updated', '03', 'order']
#
# ROW ends here; added 5 to ROW:
# ['DEF', 'updated', '03', 'order', 5]
#
# appended finalized row to LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2], ['DEF', 'updated', '02', '22341', 8], ['DEF', 'updated', '02', 'order', 2], ['DEF', 'updated', '03', 'order', 5]]
#
# removed latest entry from ROW again:
# ['DEF', 'updated', '03', 'order']
#
# current val 5 processed.
#
# removed latest level from ROW:
# ['DEF', 'updated', '03']
#
# all items iterated; returning:
#  ROW:
# ['DEF', 'updated', '03']
#  LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2], ['DEF', 'updated', '02', '22341', 8], ['DEF', 'updated', '02', 'order', 2], ['DEF', 'updated', '03', 'order', 5]]
#
# received:
#  ROW: ['DEF', 'updated', '03']
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2], ['DEF', 'updated', '02', '22341', 8], ['DEF', 'updated', '02', 'order', 2], ['DEF', 'updated', '03', 'order', 5]]
#
# current val {'order': 5} processed.
#
# removed latest level from ROW:
# ['DEF', 'updated']
#
# all items iterated; returning:
#  ROW:
# ['DEF', 'updated']
#  LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2], ['DEF', 'updated', '02', '22341', 8], ['DEF', 'updated', '02', 'order', 2], ['DEF', 'updated', '03', 'order', 5]]
#
# received:
#  ROW: ['DEF', 'updated']
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2], ['DEF', 'updated', '02', '22341', 8], ['DEF', 'updated', '02', 'order', 2], ['DEF', 'updated', '03', 'order', 5]]
#
# current val {'12': {'22338': 5, '22339': 5}, '01': {'22339': 1, '22340': 2, '22341': 2}, '02': {'22341': 8, 'order': 2}, '03': {'order': 5}} processed.
#
# removed latest level from ROW:
# ['DEF']
#
# all items iterated; returning:
#  ROW:
# ['DEF']
#  LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2], ['DEF', 'updated', '02', '22341', 8], ['DEF', 'updated', '02', 'order', 2], ['DEF', 'updated', '03', 'order', 5]]
#
# received:
#  ROW: ['DEF']
#  LOL: [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2], ['DEF', 'updated', '02', '22341', 8], ['DEF', 'updated', '02', 'order', 2], ['DEF', 'updated', '03', 'order', 5]]
#
# current val {'open': {}, 'updated': {'12': {'22338': 5, '22339': 5}, '01': {'22339': 1, '22340': 2, '22341': 2}, '02': {'22341': 8, 'order': 2}, '03': {'order': 5}}} processed.
#
# removed latest level from ROW:
# []
#
# all items iterated; returning:
#  ROW:
# []
#  LOL:
# [['ABC', 'open', {}], ['ABC', 'updated', '12', '22334', 5], ['ABC', 'updated', '12', '22335', 5], ['ABC', 'updated', '01', '22335', 1], ['ABC', 'updated', '01', '22336', 2], ['ABC', 'updated', '01', '22337', 2], ['ABC', 'updated', '02', '22337', 8], ['ABC', 'updated', '02', 'order', 2], ['ABC', 'updated', '03', 'order', 5], ['DEF', 'open', {}], ['DEF', 'updated', '12', '22338', 5], ['DEF', 'updated', '12', '22339', 5], ['DEF', 'updated', '01', '22339', 1], ['DEF', 'updated', '01', '22340', 2], ['DEF', 'updated', '01', '22341', 2], ['DEF', 'updated', '02', '22341', 8], ['DEF', 'updated', '02', 'order', 2], ['DEF', 'updated', '03', 'order', 5]]

# %%
# Code from above, without all the explanatory print statements but
#  with nicer naming

def recurse(d, table=None, row=None):
    """Recursively flatten sparse dict `d` into list of lists `table`."""
    
    if not row:
        row = [] 
    if not table:
        table = []
    
    for k, v in d.items():
        row.append(k)
        if v and isinstance(v, dict):
            table, row = recurse(d=v, table=table, row=row)
        else:
            row.append(v)
            table.append(row[:])
            row.pop()
        row.pop()
        
    return table, row

# %%
import pandas as pd

# retrieve table content as a list of lists, where each (inner) list
#  equals one row in the final table
table_as_list_of_lists, _ = recurse(sparse_sample_dict)

# convert list of lists (i.e., rows) to pandas.DataFrame
df = pd.DataFrame(table_as_list_of_lists)

# proof
df.head()
# Out:
#      0        1   2      3    4
# 0  ABC     open  {}   None  NaN
# 1  ABC  updated  12  22334  5.0
# 2  ABC  updated  12  22335  5.0
# 3  ABC  updated  01  22335  1.0
# 4  ABC  updated  01  22336  2.0
